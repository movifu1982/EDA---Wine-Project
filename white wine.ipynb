# %%
#white wines!

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
white_wine = pd.read_csv('https://archive.ics.uci.edu/ml/machine-learning-databases/wine-quality/winequality-white.csv', sep=";")

# %%
white_wine['quality_label'] = white_wine['quality'].apply(lambda value: 'low'
if value <= 4 else 'medium'
if value <= 6 else 'high')

# 3 4 5 are low, 6 7 medium, 8 and nonexistent 9 is high
#changed to: 3 4 low, 5 6 medium, 7 8 high

white_wine['quality_label'] = pd.Categorical(white_wine['quality_label'],
categories=['low', 'medium', 'high'])

# %%
white_wine
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.0              0.27         0.36            20.7      0.045
# 1               6.3              0.30         0.34             1.6      0.049
# 2               8.1              0.28         0.40             6.9      0.050
# 3               7.2              0.23         0.32             8.5      0.058
# 4               7.2              0.23         0.32             8.5      0.058
# ...             ...               ...          ...             ...        ...
# 4893            6.2              0.21         0.29             1.6      0.039
# 4894            6.6              0.32         0.36             8.0      0.047
# 4895            6.5              0.24         0.19             1.2      0.041
# 4896            5.5              0.29         0.30             1.1      0.022
# 4897            6.0              0.21         0.38             0.8      0.020
#
# ...

# %%
sns.scatterplot(x="quality", y="alcohol", data=white_wine, hue="chlorides", size="density")
# Out:
# <AxesSubplot:xlabel='quality', ylabel='alcohol'>

# %%
sns.histplot(white_wine["alcohol"], kde=True, bins=30)
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='Count'>

# %%
sns.barplot(x="quality", y="alcohol", data=white_wine)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='alcohol'>

# %%
sns.boxplot(x="alcohol", y="pH", data=white_wine, hue="quality")
# Out:
# <AxesSubplot:xlabel='alcohol', ylabel='pH'>

# %%
sns.jointplot(x="alcohol",y="pH", data=white_wine, kind="reg")

# %%
sns.heatmap(white_wine.corr(), annot=True, cmap="coolwarm")
# Out:
# <AxesSubplot:>

# %%
sns.barplot(x= "quality", y="alcohol", data=white_wine)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='alcohol'>

# %%
sns.histplot(data=white_wine, x="quality_label", color="lightpink")
# Out:
# <AxesSubplot:xlabel='quality_label', ylabel='Count'>
